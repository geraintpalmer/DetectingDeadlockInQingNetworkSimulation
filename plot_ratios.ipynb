# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import csv
import seaborn as sns
sns.set(style="whitegrid")
# Out:
# /Users/geraintianpalmer/Documents/DetectingDeadlockInQingNetworkSimulation/venv/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
bound_data = []
file_name = 'data_for_graphs/ratio_bound_data.csv'
data_file = open(file_name, 'r')
rdr = csv.reader(data_file)
for row in rdr:
    bound_data.append([float(obs) for obs in row])

# %%
print bound_data[0]
# Out:
# [0.1, 0.1, 1.0, 1.0, 0.0, 0.0, 0.2, 0.2, 0.2, 0.2, 80.0, 57.14912280701755, 3.5009596928982725]

# %%
ratios = [row[-1] for row in bound_data]

# %%
ratios_inverse = [1.0/obs for obs in ratios]

# %%
min(ratios_inverse)
# Out:
# 1.978674854082474e-05

# %%
fig, ax = plt.subplots()
#plt.hist(ratios_inverse, bins=20, edgecolor="black", color="seagreen")
sns.distplot(ratios_inverse, bins=20, hist_kws={"alpha":0.9, "color":"seagreen"}, kde_kws={"color":'black'})
plt.xlabel(r"$\beta$")
plt.ylabel('Normalised Frequency')
plt.xlim(0, 1)
ax.set_title('Histogram of ' + r"$\beta$", fontsize=20)
plt.show()
fig.savefig('betahist.pdf')
