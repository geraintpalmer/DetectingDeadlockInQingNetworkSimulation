# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import csv
from sklearn import cluster
import numpy as np
import seaborn as sns
import random
sns.set(style="whitegrid")
# Out:
# /Users/geraintianpalmer/Documents/DetectingDeadlockInQingNetworkSimulation/venv/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
bound_data = []
file_name = 'data_for_graphs/clustered_bound_data_2.csv'
data_file = open(file_name, 'r')
rdr = csv.reader(data_file)
for row in rdr:
    bound_data.append([float(obs) for obs in row])

# %%
sample_data = random.sample(bound_data, 1000000)

# %%
groups = [0, 1, 2]
ratios = [[row[-2] for row in sample_data if row[-1] == g] for g in groups]
p3s = [[row[-3] for row in sample_data if row[-1] == g] for g in groups]
p1s = [[row[-5] for row in sample_data if row[-1] == g] for g in groups]

# %%
colours = ['darkcyan', 'forestgreen', 'orangered']
labels = ['Group A', 'Group C', 'Group B']

# %%
fig, ax = plt.subplots()
for i in range(3):
    plt.scatter(p3s[i], ratios[i], marker='o', facecolors='none', alpha=0.6, edgecolors=colours[i])
for i in [0, 2, 1]:
    plt.scatter([], [], color=colours[i], label=labels[i])
plt.xlabel(r"$p_{(-3)}$")
plt.ylabel('Ratios')
ax.set_title('Scatterplot ' + r"$p_{(-3)}$" + ' vs ' + r"$E$", fontsize=20)
ax.set_ylim([0,1])
ax.set_xlim([0,0.7])
plt.legend(fontsize=14, loc='best')
plt.show()

fig, ax = plt.subplots()
for i in range(3):
    plt.scatter(p1s[i], ratios[i], marker='o', facecolors='none', alpha=0.6, edgecolors=colours[i])
for i in [0, 2, 1]:
    plt.scatter([], [], color=colours[i], label=labels[i])
plt.xlabel(r"$p_{(-1)}$")
plt.ylabel('Ratios')
ax.set_title('Scatterplot ' + r"$p_{(-1)}$" + ' vs ' + r"$E$", fontsize=20)
ax.set_ylim([0,1])
ax.set_xlim([0,1])
plt.legend(fontsize=14, loc='upper center')
plt.show()

# %%
print [min(row) for row in ratios]
print [max(row) for row in ratios]
# Out:
# [6.386718773433874e-05, 0.4050851397052847, 0.26654371911584424]
# [0.2665429327566412, 0.8838851383491835, 0.40508457773954243]

# %%
colours = ['darkcyan', 'forestgreen', 'orangered']
labels = [r"$0.0000000 < E \leq 0.2665300$",r"$0.4050855 < E \leq 1.0000000$", r"$0.2665300 < E \leq 0.4050855$"]

# %%
fig, ax = plt.subplots()
for i in range(3):
    plt.scatter(p3s[i], ratios[i], marker='o', facecolors='none', alpha=0.6, edgecolors=colours[i])
for i in [0, 2, 1]:
    plt.scatter([], [], color=colours[i], label=labels[i])
plt.xlabel(r"$p_{(-3)}$")
plt.ylabel('Ratios')
ax.set_title('Scatterplot ' + r"$p_{(-3)}$" + ' vs ' + r"$E$", fontsize=20)
ax.set_ylim([0,1])
ax.set_xlim([0,0.7])
plt.legend(fontsize=14, loc='best')
plt.show()

fig, ax = plt.subplots()
for i in range(3):
    plt.scatter(p1s[i], ratios[i], marker='o', facecolors='none', alpha=0.6, edgecolors=colours[i])
for i in [0, 2, 1]:
    plt.scatter([], [], color=colours[i], label=labels[i])
plt.xlabel(r"$p_{(-1)}$")
plt.ylabel('Ratios')
ax.set_title('Scatterplot ' + r"$p_{(-1)}$" + ' vs ' + r"$E$", fontsize=20)
ax.set_ylim([0,1])
ax.set_xlim([0,1])
plt.legend(fontsize=14, loc='upper center')
plt.show()
